# %%
import matplotlib.pyplot as plt

#fill these in
models = ["Transformer", "LSTM+Attention"]

accuracy = [0.00, 0.00]          # Replace
training_time = [0.00, 0.00]     # Replace
inference_time = [0.00, 0.00]    # Replace
gpu_memory = [0.00, 0.00]        # Replace

plt.figure(figsize=(15, 4))

# Accuracy
plt.subplot(1, 3, 1)
plt.bar(models, accuracy)
plt.title("Accuracy")
plt.ylim(0, 1)

# Training Time
plt.subplot(1, 3, 2)
plt.bar(models, training_time)
plt.title("Training Time (s)")

# GPU Memory
plt.subplot(1, 3, 3)
plt.bar(models, gpu_memory)
plt.title("GPU Memory (GB)")

plt.show()
