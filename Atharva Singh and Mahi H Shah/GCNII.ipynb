# %% [markdown]
# <a href="https://colab.research.google.com/github/ThinkingBeyond/BeyondAI-2025/blob/main/GCNII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chennnM/GCNII.git
# Out:
# Cloning into 'GCNII'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 144 (delta 6), reused 4 (delta 4), pack-reused 131 (from 1)
# Receiving objects: 100% (144/144), 5.49 MiB | 12.38 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# %cd GCNII
# Out:
# [Errno 2] No such file or directory: 'GCNII'
# /root

# %%
# %cd GCNII
# !ls
# Out:
# /content/GCNII
# data		    model.py  ppi.sh	  PyG	     splits
# full.sh		    new_data  pretrained  README.md  train.py
# full-supervised.py  ppi.py    process.py  semi.sh    utils.py
